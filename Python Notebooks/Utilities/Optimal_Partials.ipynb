# %%
from scipy import optimize
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Total RRs
#
# Remove the existing numbers and add your total move RRs in the array below

# %%
total_RR = np.array([2.58, 1.43, 0.02, 4.35, 9.78, 4.33, 0.08, 0.49, 0.22, 0.23, 26.8, 4, 92, 14.375, 1.7, 
            0.22, 10.87, 0.31, 0.42, 1.2, 3.77, 1.21])

# %%
# calculate RR earned based on partials
def earned_rr(partials):
    p1 = partials[0]
    p1_percent = partials[1]
    p2 = partials[2]
    p2_percent = partials[3]
    
    earned_rr = 0
    
    for rr in total_RR:
        if rr < p1: 
            earned_rr -= 1
        elif rr >= p1 and rr <= p2:
            earned_rr += p1*p1_percent
        elif rr >= p2:
            earned_rr += p2*p1_percent*p2_percent
    
    return earned_rr

# the closer we are to the toal RR possible, the better
def earned_rr_loss(partials):   
    return np.sum(total_RR) - earned_rr(partials)

# %%
# limit partial percentages to equal 1 since we can't take off more than 100% of a position
cons = [
    {'type': 'eq', 'fun': lambda x: x[1] + x[3] - 1 }
]

largest_total_rr = np.max(total_RR)

# %% [markdown]
# ## First Partial Information
#
# Edit `largest_first_partial` to match the largest first partial you want to take
#
# Edit `first_partial_step` to check every X number between 0 and `largest_first_partial`
#
# ### Note: Setting `first_partial_step` to lower numbers requires longer runtime

# %%
largest_first_partial = 10
first_partial_step = 1
first_partials = list(range(0, largest_first_partial, first_partial_step))

# %% [markdown]
# ## Second Partial Information
#
# Edit `second_partial_step` to check every X number between your `largest_first_partial` and largest total partial
#
# ### Note: Setting `second_partial_step` to lower numbers requires longer runtime

# %%
second_partial_step = 10 
second_partials = list(range(largest_first_partial, int(largest_total_rr), second_partial_step))

# %%
columns = ['Earned RR', 'First Partial Value', 'First Partial %', 'Second Partial Value', 'Second Partial %']
rrs = pd.DataFrame(columns=columns)

# %%
for fp in first_partials:
    for sp in second_partials:
        optimized = optimize.minimize(earned_rr_optimizer, [fp, 0.5, sp, 0.5], 
                              bounds=((0, largest_total_rr), (0, 1.), (0, largest_total_rr), (0, 1.)), method='trust-constr', constraints=cons)
        rrs = rrs.append(
            {
              'Earned RR': earned_rr(optimized.x), 
              'First Partial Value': optimized.x[0], 
              'First Partial %': optimized.x[1], 
              'Second Partial Value': optimized.x[2], 
              'Second Partial %': optimized.x[3]
             }, ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_hessian_update_strategy.py:187: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   'approximations.', UserWarning)

# %%
# values may differ slighly per run based on how well the optimizer finds a minimum but it shouldn't matter if you round 
max_rr_row = rrs.iloc[rrs['Earned RR'].idxmax()]
print(f'''The most "Total RR" achieved is {max_rr_row['Earned RR']:.3f} by takning {max_rr_row['First Partial %']:.2f}% off at {max_rr_row['First Partial Value']:.3f}
      RR and then {max_rr_row['Second Partial %']:.2f}% off at {max_rr_row['Second Partial Value']:.3f} RR''')
# Out:
# The most total RR achieved is 29.154 by takning 0.68% off at 9.755
#       RR and then 0.32% off at 90.059 RR

# %%
rrs
# Out:
#     Earned RR  First Partial Value  ...  Second Partial Value  Second Partial %
# 0    5.977528             2.987240  ...             10.552142          0.230193
# 1    7.502894             1.988197  ...             20.150555          0.254235
# 2    3.955773             0.684637  ...             30.022377          0.499996
# 3   13.708192             3.864126  ...             40.131438          0.263689
# 4    8.971979             0.687198  ...             50.020674          0.499997
# 5   13.529134             2.110024  ...             60.066700          0.252196
# 6   25.113447             9.773867  ...             70.420936          0.303734
# 7   17.509033             6.307489  ...             80.167481          0.301929
# 8   19.001072             2.086628  ...             89.928168          0.252108
# 9    8.592529             3.624279  ...             10.609927          0.303677
# 10  12.959716             3.500855  ...             20.115510          0.150047
# 11   5.408770             1.462840  ...             30.022701          0.336557
# 12   7.646760             1.463665  ...             40.021559          0.336616
# 13  18.046534             3.598388  ...             50.089928          0.202123
# 14  20.600112             3.742166  ...             60.136538          0.297325
# 15  19.268195             3.784996  ...             70.111403          0.323139
# 16  24.894448             3.767013  ...             79.991178          0.300565
# 17  22.214503             4.311168  ...             89.839160          0.377331
# 18   8.702310             3.765952  ...             10.481241          0.189715
# 19   9.830511             3.103285  ...             20.130325          0.070556
# 20  15.824504             3.602699  ...             30.064960          0.002489
# 21  17.219476             3.769330  ...             40.082460          0.006713
# 22  13.398404             2.363218  ...             50.018772          0.293327
# 23  14.444779             2.799911  ...             60.036644          0.194236
# 24  16.069636             2.658751  ...             70.027753          0.249054
# 25  22.429031             3.995412  ...             80.075700          0.339460
# 26  22.743757             2.489563  ...             89.961164          0.313568
# 27   8.782134             3.767796  ...             10.231826          0.239743
# 28  11.595668             3.272705  ...             20.039185          0.275802
# 29  13.027814             3.860113  ...             30.043953          0.002380
# 30  13.965713             3.274589  ...             40.016160          0.275624
# 31  15.962335             3.274636  ...             50.015205          0.275628
# 32  20.676585             3.750999  ...             60.031142          0.212380
# 33  19.948262             3.273540  ...             70.012338          0.275573
# 34  22.643649             3.377755  ...             80.011237          0.287592
# 35  26.904215             3.761933  ...             89.952555          0.373403
# 36   8.711473             3.769844  ...             10.137886          0.235636
# 37  11.006688             3.935243  ...             20.071649          0.118487
# 38   9.566646             4.085778  ...             30.040441          0.009944
# 39  10.754735             3.438195  ...             40.000620          0.499935
# 40  14.496508             3.993149  ...             49.351201          0.406467
# 41  20.791605             3.757198  ...             60.018882          0.258845
# 42  22.733862             3.768580  ...             70.018794          0.248758
# 43  24.602252             3.736444  ...             80.014100          0.271567
# 44  26.435340             3.663868  ...             89.977495          0.303521
# 45   5.008621             8.543523  ...             16.215683          0.455097
# 46   2.218526             5.174193  ...             20.055742          0.264025
# 47   6.591013             5.847605  ...             30.076710          0.035749
# 48   6.015872             5.176175  ...             40.020264          0.263377
# 49  12.270804             6.790050  ...             50.067342          0.329646
# 50  13.642627             6.770699  ...             60.147816          0.402794
# 51  14.877595             6.374800  ...             70.092590          0.419050
# 52  25.235720             9.731408  ...             80.388682          0.417051
# 53  28.672957             9.744001  ...             90.047192          0.361337
# 54   6.718886             9.508373  ...             16.006844          0.445765
# 55   8.540951             8.010742  ...             20.496618          0.129459
# 56  11.222090             7.048143  ...             30.079080          0.029911
# 57   9.508986             6.281260  ...             40.027534          0.194989
# 58  10.822936             6.148798  ...             50.016223          0.260987
# 59  19.675854             8.970943  ...             60.221447          0.368437
# 60  21.669636             9.077406  ...             70.185806          0.398227
# 61  25.953189             9.304292  ...             80.246456          0.288141
# 62  18.526191             6.148215  ...             89.962691          0.261008
# 63   8.476865             9.687432  ...             14.574000          0.352198
# 64   7.449494             7.558550  ...             20.137340          0.157716
# 65  14.801317             7.963501  ...             30.065856          0.021611
# 66  20.749281             9.430619  ...             40.103912          0.015090
# 67  13.725216             7.128454  ...             50.013939          0.259485
# 68  15.820419             7.189750  ...             60.014283          0.248854
# 69  24.849857             9.769411  ...             70.139446          0.318930
# 70  26.197902             9.775544  ...             80.199248          0.376960
# 71  29.154428             9.754818  ...             90.059447          0.316095
# 72  -2.172636             8.209081  ...             10.348845          0.429082
# 73  12.511940             9.769431  ...             20.331577          0.019264
# 74  18.628433             8.930082  ...             30.057575          0.015029
# 75  18.513886             8.876043  ...             40.054946          0.002177
# 76  21.954698             9.737789  ...             50.091422          0.000318
# 77  23.464354             9.717260  ...             60.063369          0.108845
# 78  25.449814             9.760639  ...             70.117364          0.244154
# 79  26.805048             9.732897  ...             80.113293          0.329327
# 80  24.662085             8.122044  ...             89.967514          0.310729
# 81  -1.311693             9.370549  ...             10.600153          0.441543
# 82  10.926079             9.099705  ...             20.033384          0.258011
# 83  21.748364             9.711367  ...             29.998142          0.010595
# 84  22.107898             9.776913  ...             40.049603          0.000262
# 85  19.586580             9.100429  ...             50.010835          0.257784
# 86  23.339490             9.701553  ...             60.037084          0.101154
# 87  24.401302             9.478978  ...             70.014193          0.176655
# 88  26.966282             9.755963  ...             80.044297          0.318771
# 89  27.426807             9.120668  ...             89.962804          0.290617
#
# [90 rows x 5 columns]
